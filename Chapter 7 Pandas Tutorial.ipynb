# %%
import pandas as pd

# %%
# Read excel file. 
# Error read_csv didnot allow e to read specific sheet name
df=pd.read_excel('Master_Sheet_Ram_V4.xlsx', sheet_name = 'Master_Sheet')

# %%
# Declaring dictionary data type to be converted into data frame. 
# Error The 
Dict_Data={
    'Name': ['Ram kinker', 'Ram Mohan','Ram Nayan','Ram Sharan'],
    'Age': [35,40,45,46],
    'Weight': [100, 90, 96, 100]
}

# %%
# Access different things related to dictionary
Dict_Data['Weight'][0]
Dict_Data['Name'][0]

Dict_Data.keys()
Dict_Data.values()
Dict_Data.items()
# Out:
# dict_items([('Name', ['Ram kinker', 'Ram Mohan', 'Ram Nayan', 'Ram Sharan']), ('Age', [35, 40, 45, 46]), ('Weight', [100, 90, 96, 100])])

# %%
df_dict=pd.DataFrame.from_dict(Dict_Data)
df_dict
df_dict.head(2)
df.tail(2)
# Out:
#            Study Patient_ID  Years_Education  3-mon FU fall (0: no; 1: yes)  \
# 644   VACOPD 051        NaN              NaN                            NaN
# 645  VA COPD 052        NaN              NaN                            NaN
#
#      3-mon FU DFU (0: no; 1: yes)  6-mon FU fall (0: no; 1: yes)  \
# 644                           NaN                            NaN
# 645                           NaN                            NaN
#
#      6-mon FU DFU (0: no; 1: yes)  1-year FU fall (0: no; 1: yes)  \
# 644                           NaN                             NaN
# 645                           NaN                             NaN
#
#      1-year FU DFU (0: no; 1: yes)  Group (0: control; 1: intervention)  ...  \
# 644                            NaN                                  NaN  ...
# 645                            NaN                                  NaN  ...
#
#      FUDT_L_Extension Time Reduction, %  \
# 644                                 NaN
# ...

# %%
# Get the column names
df.columns
# Get the types of data in the data frame
df.dtypes
# Out:
# Study                                               object
# Patient_ID                                          object
# Years_Education                                    float64
# 3-mon FU fall (0: no; 1: yes)                      float64
# 3-mon FU DFU (0: no; 1: yes)                       float64
#                                                     ...
# FUDT_L_Extension Acceleration Time CV, %           float64
# FUDT_L_Extension Acceleration Time Reduction, %    float64
# FUDT_L_Rate Average, reps./min                     float64
# FUDT_L_Rate CV, %                                  float64
# FUDT_L_Rate Reduction, %                           float64
# Length: 874, dtype: object

# %%
# Understanding data is most crucial part of data science
df.describe()
# Above command give details about integer and float only. 
# However, if we want to explore the categorical variable then we should use below command.
df.describe(include='object')
# Out:
#             Study  Patient_ID  \
# count         646         434
# unique        646         362
# top     SunCity18         125
# freq            1           4
#
#        Race (0: American Indian; 1:  Asian; 2: Black; 3: Native Hawaiian; 4: White; 5: Other)  \
# count                                                 244
# unique                                                 26
# top                                                Qatari
# freq                                                   41
#
#         Ethnicity(0: Non-hispanic; 1: Hispanic)  \
# count                                       302
# unique                                       10
# top                                           0
# freq                                         91
#
#         BL_Slowness (Not Frail: 0; Frail: 1)  BL_MOCA  BL_FES-I  TUG_FU  \
# count                                    433      545       514   46.00
# unique                                     4       27        54   46.00
# ...

# %%
df[(df['Years_Education']>10) & (df['Years_Education']>5)]
# Out:
#          Study Patient_ID  Years_Education  3-mon FU fall (0: no; 1: yes)  \
# 81   MCI_Itmt1     MCI001             19.0                            NaN
# 83   MCI_Itmt3     MCI003             21.0                            NaN
# 84   MCI_Itmt4     MCI004             19.0                            NaN
# 85   MCI_Itmt5     MCI005             18.0                            NaN
# 86   MCI_Itmt6     MCI006             16.0                            NaN
# ..         ...        ...              ...                            ...
# 322  SunCity26        NaN             16.0                            NaN
# 323  SunCity27        NaN             18.0                            NaN
# 324  SunCity28        NaN             15.0                            NaN
# 325  SunCity29        NaN             16.0                            NaN
# 326  SunCity30        NaN             16.0                            NaN
#
#      3-mon FU DFU (0: no; 1: yes)  6-mon FU fall (0: no; 1: yes)  \
# ...

# %% [markdown]
# # Indexing with iloc
